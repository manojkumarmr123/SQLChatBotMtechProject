# %% [markdown]
# # Time Series Forecasting
# ## Using Machine Learning to Forecast Sales

# %%
#!pip install xgboost

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Types of Time Series Data
#
# ![](https://miro.medium.com/max/1400/1*V_RKPeIxCB9CS_2SsLyKXw.jpeg)
#
# reference: https://engineering.99x.io/time-series-forecasting-in-machine-learning-3972f7a7a467

# %%
import sqlalchemy as db

db_user = "galaxyqlikuatuser"
db_password = "GalaxyQlik$1uatuser"
db_host = "lyradatamartnew.csenulcs9jlk.us-west-2.redshift.amazonaws.com:5439"
db_name = "galaxy"

engine = db.create_engine("postgresql://galaxyqlikuatuser:GalaxyQlik$1uatuser@lyradatamartnew.csenulcs9jlk.us-west-2.redshift.amazonaws.com:5439/galaxy")

cnn = engine.connect()

# %%
sqlquery = """select order_date,sum(card_value) as tdv from dm_qlik_reports.orders o
join dm_qlik_reports.cards c on o.order_id = c.order_id
group by order_date"""
sqlquery
# Out:
# 'select order_date,sum(card_value) as tdv from dm_qlik_reports.orders o\njoin dm_qlik_reports.cards c on o.order_id = c.order_id\ngroup by order_date'

# %%
df = pd.read_sql_query(sqlquery,cnn,index_col='order_date')
df.index = pd.to_datetime(df.index)
df
# Out:
#               tdv
# order_date
# 2024-03-20  758.0
# 2024-04-08  674.0
# 2024-03-27  719.0
# 2024-04-06  550.0
# 2024-03-30  729.0
# ...           ...
# 2024-07-30  298.0
# 2024-08-08  271.0
# 2024-08-10  428.0
# 2024-08-15  287.0
# 2024-08-22  446.0
#
# [156 rows x 1 columns]

# %%
df.plot(
        figsize=(15, 5),
        color=color_pal[0],
        title='TDV Sales')
plt.show()

# %% [markdown]
# # Train / Test Split

# %%
train = df.loc[df.index < '08-01-2024']
test = df.loc[df.index >= '08-01-2024']

fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('08-01-2024', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %%
df.loc[(df.index > '07-01-2024') & (df.index < '07-08-2024')] \
    .plot(figsize=(15, 5), title='Week Of Data')
plt.show()

# %% [markdown]
# # Feature Creation

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

df
# Out:
#               tdv  dayofweek  quarter  month  year  dayofyear  dayofmonth  \
# order_date
# 2024-03-20  758.0          2        1      3  2024         80          20
# 2024-04-08  674.0          0        2      4  2024         99           8
# 2024-03-27  719.0          2        1      3  2024         87          27
# 2024-04-06  550.0          5        2      4  2024         97           6
# 2024-03-30  729.0          5        1      3  2024         90          30
# ...           ...        ...      ...    ...   ...        ...         ...
# 2024-07-30  298.0          1        3      7  2024        212          30
# 2024-08-08  271.0          3        3      8  2024        221           8
# 2024-08-10  428.0          5        3      8  2024        223          10
# 2024-08-15  287.0          3        3      8  2024        228          15
# 2024-08-22  446.0          3        3      8  2024        235          22
#
#             weekofyear
# order_date
# 2024-03-20          12
# 2024-04-08          15
# 2024-03-27          13
# 2024-04-06          14
# 2024-03-30          13
# ...                ...
# 2024-07-30          31
# 2024-08-08          32
# 2024-08-10          32
# 2024-08-15          33
# 2024-08-22          34
#
# [156 rows x 8 columns]

# %% [markdown]
# # Visualize our Feature / Target Relationship

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='month', y='tdv')
ax.set_title('TDV by Month')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='month', y='tdv', palette='Blues')
ax.set_title('TDV by Month')
plt.show()

# %% [markdown]
# # Create our Model

# %%
train = create_features(train)
test = create_features(test)

FEATURES = ['dayofyear', 'dayofweek', 'quarter', 'month', 'year']
TARGET = 'tdv'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:599.97984	validation_1-rmse:665.56205
# [100]	validation_0-rmse:330.58628	validation_1-rmse:427.74594
# [200]	validation_0-rmse:261.74872	validation_1-rmse:344.10712
# [300]	validation_0-rmse:240.23997	validation_1-rmse:311.77294
# [400]	validation_0-rmse:229.32090	validation_1-rmse:300.37177
# [500]	validation_0-rmse:221.10398	validation_1-rmse:296.35822
# C:\Users\mkuma00\AppData\Local\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [17:39:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [579]	validation_0-rmse:214.37158	validation_1-rmse:296.18585
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, objective='reg:linear', ...)

# %% [markdown]
# # Feature Importance

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %% [markdown]
# # Forecast on Test

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df[['tdv']].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
ax = df.loc[(df.index > '08-01-2024') & (df.index < '08-08-2024')]['tdv'] \
    .plot(figsize=(15, 5), title='Week Of Data')
df.loc[(df.index > '08-01-2024') & (df.index < '08-08-2024')]['prediction'] \
    .plot(style='.')
plt.legend(['Truth Data','Prediction'])
plt.show()

# %% [markdown]
# # Score (RMSE)

# %%
score = np.sqrt(mean_squared_error(test['tdv'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 296.13

# %% [markdown]
# # Calculate Error
# - Look at the worst and best predicted days

# %%
test['error'] = np.abs(test[TARGET] - test['prediction'])
test['date'] = test.index.date
test.groupby(['date'])['error'].mean().sort_values(ascending=False).head(10)
# Out:
# date
# 2024-08-12    449.714508
# 2024-08-06    444.191772
# 2024-08-19    419.714508
# 2024-08-18    407.643829
# 2024-08-01    395.883240
# 2024-08-17    381.116760
# 2024-08-02    341.883240
# 2024-08-04    334.356171
# 2024-08-21    317.883240
# 2024-08-14    312.883240
# Name: error, dtype: float64

# %%
from datetime import datetime, timedelta

# Get the current date
current_date = datetime.now().date()

# Calculate the date one year from the current date
end_date = current_date + timedelta(days=365)

# Create a date range from the current date to the end date
date_range = pd.date_range(start=current_date, end=end_date)

# Convert the date range to a DataFrame
df_future = pd.DataFrame(date_range, columns=['Date'])

# Display the DataFrame
df_future = df.set_index('Date')
df_future.index = pd.to_datetime(df_future.index)

df_future.rename_axis('order_date', inplace=True)

#print(df)
df_future
# Out:
# Empty DataFrame
# Columns: []
# Index: [2024-08-25 00:00:00, 2024-08-26 00:00:00, 2024-08-27 00:00:00, 2024-08-28 00:00:00, 2024-08-29 00:00:00, 2024-08-30 00:00:00, 2024-08-31 00:00:00, 2024-09-01 00:00:00, 2024-09-02 00:00:00, 2024-09-03 00:00:00, 2024-09-04 00:00:00, 2024-09-05 00:00:00, 2024-09-06 00:00:00, 2024-09-07 00:00:00, 2024-09-08 00:00:00, 2024-09-09 00:00:00, 2024-09-10 00:00:00, 2024-09-11 00:00:00, 2024-09-12 00:00:00, 2024-09-13 00:00:00, 2024-09-14 00:00:00, 2024-09-15 00:00:00, 2024-09-16 00:00:00, 2024-09-17 00:00:00, 2024-09-18 00:00:00, 2024-09-19 00:00:00, 2024-09-20 00:00:00, 2024-09-21 00:00:00, 2024-09-22 00:00:00, 2024-09-23 00:00:00, 2024-09-24 00:00:00, 2024-09-25 00:00:00, 2024-09-26 00:00:00, 2024-09-27 00:00:00, 2024-09-28 00:00:00, 2024-09-29 00:00:00, 2024-09-30 00:00:00, 2024-10-01 00:00:00, 2024-10-02 00:00:00, 2024-10-03 00:00:00, 2024-10-04 00:00:00, 2024-10-05 00:00:00, 2024-10-06 00:00:00, 2024-10-07 00:00:00, 2024-10-08 00:00:00, 2024-10-09 00:00:00, 2024-10-10 00:00:00, 2024-10-11 00:00:00, 2024-10-12 00:00:00, 2024-10-13 00:00:00, 2024-10-14 00:00:00, 2024-10-15 00:00:00, 2024-10-16 00:00:00, 2024-10-17 00:00:00, 2024-10-18 00:00:00, 2024-10-19 00:00:00, 2024-10-20 00:00:00, 2024-10-21 00:00:00, 2024-10-22 00:00:00, 2024-10-23 00:00:00, 2024-10-24 00:00:00, 2024-10-25 00:00:00, 2024-10-26 00:00:00, 2024-10-27 00:00:00, 2024-10-28 00:00:00, 2024-10-29 00:00:00, 2024-10-30 00:00:00, 2024-10-31 00:00:00, 2024-11-01 00:00:00, 2024-11-02 00:00:00, 2024-11-03 00:00:00, 2024-11-04 00:00:00, 2024-11-05 00:00:00, 2024-11-06 00:00:00, 2024-11-07 00:00:00, 2024-11-08 00:00:00, 2024-11-09 00:00:00, 2024-11-10 00:00:00, 2024-11-11 00:00:00, 2024-11-12 00:00:00, 2024-11-13 00:00:00, 2024-11-14 00:00:00, 2024-11-15 00:00:00, 2024-11-16 00:00:00, 2024-11-17 00:00:00, 2024-11-18 00:00:00, 2024-11-19 00:00:00, 2024-11-20 00:00:00, 2024-11-21 00:00:00, 2024-11-22 00:00:00, 2024-11-23 00:00:00, 2024-11-24 00:00:00, 2024-11-25 00:00:00, 2024-11-26 00:00:00, 2024-11-27 00:00:00, 2024-11-28 00:00:00, 2024-11-29 00:00:00, 2024-11-30 00:00:00, 2024-12-01 00:00:00, 2024-12-02 00:00:00, ...]
#
# [366 rows x 0 columns]

# %%
df_future.dtypes
# Out:
# Series([], dtype: object)

# %%
df_future = create_features(df_future)

#df_future = df_future[dayofyear, dayofweek, quarter, month, year]
df_future.drop(columns=['dayofmonth', 'weekofyear'], inplace=True)
df_future
# Out:
#             dayofweek  quarter  month  year  dayofyear
# order_date
# 2024-08-25          6        3      8  2024        238
# 2024-08-26          0        3      8  2024        239
# 2024-08-27          1        3      8  2024        240
# 2024-08-28          2        3      8  2024        241
# 2024-08-29          3        3      8  2024        242
# ...               ...      ...    ...   ...        ...
# 2025-08-21          3        3      8  2025        233
# 2025-08-22          4        3      8  2025        234
# 2025-08-23          5        3      8  2025        235
# 2025-08-24          6        3      8  2025        236
# 2025-08-25          0        3      8  2025        237
#
# [366 rows x 5 columns]

# %%
new_column_order = ['dayofyear', 'dayofweek', 'quarter', 'month', 'year']

df_future = df_future[new_column_order]

df_future
# Out:
#             dayofyear  dayofweek  quarter  month  year
# order_date
# 2024-08-25        238          6        3      8  2024
# 2024-08-26        239          0        3      8  2024
# 2024-08-27        240          1        3      8  2024
# 2024-08-28        241          2        3      8  2024
# 2024-08-29        242          3        3      8  2024
# ...               ...        ...      ...    ...   ...
# 2025-08-21        233          3        3      8  2025
# 2025-08-22        234          4        3      8  2025
# 2025-08-23        235          5        3      8  2025
# 2025-08-24        236          6        3      8  2025
# 2025-08-25        237          0        3      8  2025
#
# [366 rows x 5 columns]

# %%
X_test
# Out:
#             dayofyear  dayofweek  quarter  month  year
# order_date
# 2024-08-01        214          3        3      8  2024
# 2024-08-04        217          6        3      8  2024
# 2024-08-06        219          1        3      8  2024
# 2024-08-11        224          6        3      8  2024
# 2024-08-14        227          2        3      8  2024
# 2024-08-16        229          4        3      8  2024
# 2024-08-19        232          0        3      8  2024
# 2024-08-21        234          2        3      8  2024
# 2024-08-02        215          4        3      8  2024
# 2024-08-03        216          5        3      8  2024
# 2024-08-05        218          0        3      8  2024
# 2024-08-07        220          2        3      8  2024
# 2024-08-12        225          0        3      8  2024
# 2024-08-13        226          1        3      8  2024
# 2024-08-17        230          5        3      8  2024
# 2024-08-20        233          1        3      8  2024
# 2024-08-09        222          4        3      8  2024
# 2024-08-18        231          6        3      8  2024
# 2024-08-08        221          3        3      8  2024
# 2024-08-10        223          5        3      8  2024
# 2024-08-15        228          3        3      8  2024
# 2024-08-22        235          3        3      8  2024

# %%
df_future['predicted_sales'] = reg.predict(df_future)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df_future['predicted_sales'] = reg.predict(df_future)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xgboost\sklearn.py:1186, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1184 if self._can_use_inplace_predict():
#    1185     try:
# -> 1186         predts = self.get_booster().inplace_predict(
#    1187             data=X,
#    1188             iteration_range=iteration_range,
#    1189             predict_type="margin" if output_margin else "value",
#    1190             missing=self.missing,
#    1191             base_margin=base_margin,
#    1192             validate_features=validate_features,
#    1193         )
#    1194         if _is_cupy_alike(predts):
#    1195             import cupy  # pylint: disable=import-error
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xgboost\core.py:2510, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2508     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2509     if validate_features:
# -> 2510         self._validate_features(fns)
#    2511 if _is_list(data) or _is_tuple(data):
#    2512     data = np.array(data)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xgboost\core.py:3075, in Booster._validate_features(self, feature_names)
#    3069 if my_missing:
#    3070     msg += (
#    3071         "\ntraining data did not have the following fields: "
#    3072         + ", ".join(str(s) for s in my_missing)
#    3073     )
# -> 3075 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['dayofyear', 'dayofweek', 'quarter', 'month', 'year'] ['dayofyear', 'dayofweek', 'quarter', 'month', 'year', 'predicted_sales']
# training data did not have the following fields: predicted_sales

# %%
df_future
# Out:
#             dayofyear  dayofweek  quarter  month  year  predicted_sales
# order_date
# 2024-08-25        238          6        3      8  2024       368.356171
# 2024-08-26        239          0        3      8  2024       473.285492
# 2024-08-27        240          1        3      8  2024       501.808228
# 2024-08-28        241          2        3      8  2024       555.116760
# 2024-08-29        242          3        3      8  2024       555.116760
# ...               ...        ...      ...    ...   ...              ...
# 2025-08-21        233          3        3      8  2025       555.116760
# 2025-08-22        234          4        3      8  2025       555.116760
# 2025-08-23        235          5        3      8  2025       555.116760
# 2025-08-24        236          6        3      8  2025       368.356171
# 2025-08-25        237          0        3      8  2025       473.285492
#
# [366 rows x 6 columns]

# %%
# Convert the index to a normal column
df_future = df_future.reset_index()

# Optionally, you can rename the new column
df_future.rename(columns={'index': 'organization_id'}, inplace=True)

# %%
column_select = ['order_date','predicted_sales']
df_future = df_future[column_select]
df_future
# Out:
#     order_date  predicted_sales
# 0   2024-08-25       368.356171
# 1   2024-08-26       473.285492
# 2   2024-08-27       501.808228
# 3   2024-08-28       555.116760
# 4   2024-08-29       555.116760
# ..         ...              ...
# 361 2025-08-21       555.116760
# 362 2025-08-22       555.116760
# 363 2025-08-23       555.116760
# 364 2025-08-24       368.356171
# 365 2025-08-25       473.285492
#
# [366 rows x 2 columns]

# %%
# Write DataFrame to SQL table
df_future.to_sql('predicted_tdv', cnn,schema='dm_qlik_reports', if_exists='replace', index=False)
# Out:
# 366
